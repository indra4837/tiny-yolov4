# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/My Drive/darknet/"

# %%
# !make
# !chmod +x ./darknet
# Out:
# chmod +x *.sh

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 2s (219 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# !dos2unix ./data/train.txt
# !dos2unix ./data/test.txt
# !dos2unix ./data/obj.data
# !dos2unix ./data/obj.names
# !dos2unix ./cfg/yolov4-tiny-custom.cfg
# Out:
# dos2unix: converting file ./data/train.txt to Unix format...
# dos2unix: converting file ./data/test.txt to Unix format...
# dos2unix: converting file ./data/obj.data to Unix format...
# dos2unix: converting file ./data/obj.names to Unix format...
# dos2unix: converting file ./cfg/yolov4-tiny-custom.cfg to Unix format...

# %%
# !./darknet detector train data/obj.data cfg/yolo-obj.cfg backup/yolov4-tiny-custom_17000.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 91173, rewritten_bbox = 1.498251 %
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.352209, GIOU: 0.236199), Class: 0.458265, Obj: 0.000607, No Obj: 0.000277, .5R: 0.125000, .75R: 0.000000, count: 8, class_loss = 6.031257, iou_loss = 7.589353, total_loss = 13.620610
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.462826, GIOU: 0.418971), Class: 0.443221, Obj: 0.001533, No Obj: 0.000959, .5R: 0.300000, .75R: 0.000000, count: 10, class_loss = 7.445373, iou_loss = 1.283401, total_loss = 8.728773
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.420289, GIOU: 0.329226), Class: 0.376299, Obj: 0.002110, No Obj: 0.001108, .5R: 0.217391, .75R: 0.000000, count: 23, class_loss = 14.005239, iou_loss = 0.373416, total_loss = 14.378655
#  total_bbox = 91214, rewritten_bbox = 1.497577 %
# ...
